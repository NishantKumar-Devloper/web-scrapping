# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from bs4 import BeautifulSoup as bs
import requests,smtplib

# %%
URL='https://www.amazon.com/Sleeping-Reduction-Beinkap-Reusable-Protection/dp/B0CL69TCM3/ref=sr_1_7?crid=6IZTKEF7BE6M&dib=eyJ2IjoiMSJ9.vvywda9LWkld6I72pIEPIOj5LPWWo4TSL9a13rzeFI6h81AM5ixiJxQyN6A84VVN-3HqpDTNc_f8RSNnQg37lUcJN2nqwspFVDt9ZeffsrNAoPipSMYx0Krd_l1ixXXDn69n6rv_Q88UxceKijvqWp_5h-quj13uJ25c_CmFJ6IIVLxylWkBGIIuHZ4vfosTzkSWxbkyD-tbJ1bHnQ-AxPkOzptSXwlXHPYElzGFIPqhc0RkZPdHf9Iz_44nh5rMdryoDft2p_eyTtxeAQ_ENCWdeAdfD2mQM4S6EuugbDI.SZROi_9YIG34YdDsQGnJh91z3LOrxtg6up7zhjXbCSY&dib_tag=se&keywords=ear+plugs&qid=1712464608&sprefix=eaar%2Caps%2C392&sr=8-7'

page = requests.get(URL)

soup1 = bs(page.content, "html.parser")

soup2 = bs(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text().strip()

price = soup2.find(class_='a-price-whole').get_text().replace('\n','')
price = ' '.join(price.split()).strip('.')

print(title)
print(price)
# Out:
# Ear Plugs for Sleeping Noise Reduction, Beinkap Reusable Earplugs Hearing Protection for Focus, Study, Work – 6 Pair Eartips in S/M/L – Flexible Silicone Soft – 35dB Noise Cancelling with Storage Case
# 18

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2024-04-09

# %%
import csv 

header = ['Title', 'Price', 'Date']
data = [title, int(price), today]


with open('AmazonWebScraperDataset.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv('/kaggle/working/AmazonWebScraperDataset.csv')
df
# df['Price'] = df['Price'].replace('\n', '', regex=True)
# df['Price'] = df['Price'].str.strip('.')
# df['Price'] = df.groupby(df.index)['Price'].apply(''.join)
# df['Price'] = df['Price'].replace(' +', '', regex=True)
df['Price'].dtype
# Out:
# dtype('int64')

# %%
def check_price():
    URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    
    page = requests.get(URL)

    soup1 = bs(page.content, "html.parser")

    soup2 = bs(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text().strip()

    price = soup2.find(class_='a-price-whole').get_text().replace('\n','')
    price = ' '.join(price.split()).strip('.')
    title = title.strip()

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, int(price), today]

    with open('AmazonWebScraperDataset.csv', 'a+', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    if int(price)<=18:
        send_mail()
        print('sent')

# %%
import time
while(True):
    check_price()
    time.sleep(10)
# Out:
# sent
# sent
# sent
# sent
# sent
# sent
# sent
# sent

# %%
def send_mail():
    server = smtplib.SMTP('smtp.gmail.com',587)
    server.starttls()
    server.login('senderacc@gmail.com','nwdn otip ipkl tqee')
    
    subject = "testing"
    body = "done"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail('senderacc@gmail.com','reciveracc@gmail.com',msg)
